# %%
import cv2
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import cv2
#       2 import time
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# Đọc video từ file
camera = cv2.VideoCapture(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Đọc video từ file
# ----> 2 camera = cv2.VideoCapture(0)
#
# NameError: name 'cv2' is not defined

# %%
# Tạo cửa sổ để hiển thị
cv2.namedWindow('Video Player', cv2.WINDOW_NORMAL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Tạo cửa sổ để hiển thị
# ----> 2 cv2.namedWindow('Video Player', cv2.WINDOW_NORMAL)
#
# NameError: name 'cv2' is not defined

# %%
# Ghi text trên hình ảnh
font = cv2.FONT_HERSHEY_SIMPLEX
font_color = (255, 255, 255)
font_scale = 1
font_thicknes = 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Ghi text trên hình ảnh
# ----> 2 font = cv2.FONT_HERSHEY_SIMPLEX
#       3 font_color = (255, 255, 255)
#       4 font_scale = 1
#
# NameError: name 'cv2' is not defined

# %%
# Hiển thị từng khung ảnh
while True:
    # Thời gian trước khi đọc
    start_time = time.time()
    # Đọc 1 frame
    ret, frame = camera.read()
    # Thoát khi không thể đọc được frame
    if not ret:
        break
    # Thời gian trước khi đọc
    end_time = time.time()    
    # Tình FPS:
    fps = 1/(end_time-start_time)
    # Ghi số lượng fps
    cv2.putText(frame, f'FPS: {fps:.2f}', (100, 100), font, font_scale, font_color , font_thicknes)
    # Hiển thị
    cv2.imshow('Video Player', frame)
    if(cv2.waitKey(10)==ord('q')):
        break

# Hủy bỏ player
camera.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 # Hiển thị từng khung ảnh
#       2 while True:
#       3     # Thời gian trước khi đọc
# ----> 4     start_time = time.time()
#       5     # Đọc 1 frame
#       6     ret, frame = camera.read()
#
# NameError: name 'time' is not defined
